# %%
import sys

print (sys.version)
# Out:
# 2.7.12 (default, Dec  4 2017, 14:50:18)
# [GCC 5.4.0 20160609]

# %%
import tensorflow as tf; 

print(tf.__version__)
# Out:
# 1.6.0

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.framework import ops
import cv2
import random
import os

#from tf_utils import load_dataset, random_mini_batches, convert_to_one_hot, predict

# %matplotlib inline
np.random.seed(1)

# %%
path = 'Training/'
img_w = 160
img_h = 160
n_labels = 2 #6
n_of_images= 191*2
data_shape = img_w*img_h

# %%
import matplotlib.pyplot as plt
import tensorlayer as tl
# %matplotlib inline




NoLabel = [0,0,0]

Water = [255,100,100] 

Sky = [153,17,105] 

Mountain = [0,255,0] 

Boat = [200,8,21] 

Other = [255,255,255] 

label_colours = np.array([NoLabel, Water, Sky, Mountain, Boat,
                          Other])

def visualize(temp, plot=False):
    r = temp.copy()
    g = temp.copy()
    b = temp.copy()
    for l in range(0,5):
        r[temp==l]=label_colours[l,0]
        g[temp==l]=label_colours[l,1]
        b[temp==l]=label_colours[l,2]

    rgb = np.zeros((temp.shape[0], temp.shape[1], 3), dtype=np.uint8)
    rgb[:,:,0] = (b)#[:,:,0]
    rgb[:,:,1] = (g)#[:,:,1]
    rgb[:,:,2] = (r)#[:,:,2]
    if plot:
        plt.imshow(rgb)
    else:
        return rgb
    
def normalized(bgr):
    return bgr/255.0
    #norm=np.zeros((rgb.shape[0], rgb.shape[1], 3),np.float32)

    #b=rgb[:,:,0]
    #g=rgb[:,:,1]
    #r=rgb[:,:,2]

    #norm[:,:,0]=cv2.equalizeHist(b)
    #norm[:,:,1]=cv2.equalizeHist(g)
    #norm[:,:,2]=cv2.equalizeHist(r)

    #return norm

    ##b, g, r = cv2.split(bgr)
    ##red = cv2.equalizeHist(r)
    ##green = cv2.equalizeHist(g)
    ##blue = cv2.equalizeHist(b)
    ##return cv2.merge((blue, green, red))

def binarylab(labels):
    x = np.zeros([img_h,img_w,n_labels])  
    
    for i in range(img_h):
        for j in range(img_w):
            x[i,j,labels[i][j]]=1
    return x

def prep_data(path, augmentation1, augmentation2):
    train_data = []
    train_label = []
    train_data_path = []
    train_label_path = []
    import os
    with open(path+'data.txt') as f:
        txt = f.readlines()
        txt = [line.split(' ') for line in txt]
    for i in range(len(txt)):
        image= cv2.imread(os.getcwd() + "/" + path + txt[i][0])
        image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        h,w,d=image.shape
        annotation=cv2.imread(os.getcwd() + "/" + path + txt[i][1])
        h_a,w_a,d_a=annotation.shape
        if(augmentation1==True):
            number_of_crop=int(w/img_w)
            for j in range(number_of_crop):
                Angle=random.randrange(-10,10)
                M = cv2.getRotationMatrix2D((h/2,w/2),Angle,1)
                image_crop = image[int((h/2)-(img_h/2)):int((h/2)+(img_h/2)),int((j*img_w)):int((j+1)*img_w)]
                annotation_crop = annotation[int((h/2)-(img_h/2)):int((h/2)+(img_h/2)),int((j*img_w)):int((j+1)*img_w)]
                #if(j>1 and j<number_of_crop-1):
                #    image_crop = cv2.warpAffine(image_crop,M,(img_w,img_h))
                #    annotation_crop = cv2.warpAffine(annotation_crop,M,(img_w,img_h))
                train_data.append(normalized(image_crop))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
                train_label.append(binarylab(annotation_crop[:,:,0]))
        #Angle=random.randrange(-10,10)
        #M = cv2.getRotationMatrix2D((w/2,h/2),Angle,1)
        #image_rotated = cv2.warpAffine(image,M,(w,h))
        #image_rotated = image_rotated[int((h/2)-(h/2.6)):int((h/2)+(h/2.6)), int((w/2)-(w/2.6)):int((w/2)+(w/2.6))]
        #image_rotated = cv2.resize(image_rotated,(img_w,img_h))
        #annotation_rotated = cv2.warpAffine(annotation,M,(w_a,h_a))
        #annotation_rotated = annotation_rotated[int((h/2)-(h/2.6)):int((h/2)+(h/2.6)), int((w/2)-(w/2.6)):int((w/2)+(w/2.6))]
        #annotation_rotated = cv2.resize(annotation_rotated,(img_w,img_h))
        
        if(augmentation2==True):
            image_flip=cv2.flip(image,1)
            annotation_flip=cv2.flip(annotation,1)
            image_flip=cv2.resize(image_flip,(img_w,img_h))
            annotation_flip=cv2.resize(annotation_flip,(img_w,img_h))
            train_data.append(normalized(image_flip))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
            train_label.append(binarylab(annotation_flip[:,:,0]))
            
            image_rotated,annotation_rotated= tl.prepro.rotation_multi([image, annotation],rg=20, is_random=True, fill_mode='reflect') 
            image_rotated=cv2.resize(image_rotated,(img_w,img_h))
            annotation_rotated=cv2.resize(annotation_rotated,(img_w,img_h))
            train_data.append(normalized(image_rotated))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
            train_label.append(binarylab(annotation_rotated[:,:,0]))
            
            image_shear,annotation_shear= tl.prepro.shear_multi([image, annotation], 0.05, is_random=True, fill_mode='reflect')
            image_shear=cv2.resize(image_shear,(img_w,img_h))
            annotation_shear=cv2.resize(annotation_shear,(img_w,img_h))
            train_data.append(normalized(image_shear))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
            train_label.append(binarylab(annotation_shear[:,:,0]))
            
            image_zoom,annotation_zoom=tl.prepro.zoom_multi([image, annotation],zoom_range=[0.5, 0.7], is_random=True, fill_mode='reflect')
            image_zoom=cv2.resize(image_zoom,(img_w,img_h))
            annotation_zoom=cv2.resize(annotation_zoom,(img_w,img_h))
            train_data.append(normalized(image_zoom))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
            train_label.append(binarylab(annotation_zoom[:,:,0]))
            
            image_Bright=tl.prepro.brightness(image, gamma=1, gain=1, is_random=True)
            image_Bright=cv2.resize(image_Bright,(img_w,img_h))
            annotation_Bright=cv2.resize(annotation,(img_w,img_h))
            train_data.append(normalized(image_Bright))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
            train_label.append(binarylab(annotation_Bright[:,:,0]))
            #randomRoulette=random.randrange(0,20)
            #if(randomRoulette==10):
            #    image_flipUpDown=cv2.flip(image,0)
            #    annotation_flipUpDown=cv2.flip(annotation,0)
            #    train_data.append(normalized(image_flipUpDown))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
            #    train_label.append(binarylab(annotation_flipUpDown[:,:,0]))
                
            #randomRoulette=random.randrange(0,5)
            #if(randomRoulette==3):
            #    image_blur=cv2.blur(image,(10,10))
            #    annotation_blur=cv2.blur(annotation,(10,10))
            #    train_data.append(normalized(image_blur))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
            #    train_label.append(binarylab(annotation_blur[:,:,0]))
                
                
                
            
        
        image= cv2.resize(image,(img_w,img_h))
        annotation= cv2.resize(annotation,(img_w,img_h))
        train_data.append(normalized(image))#normalized(cv2.imread(os.getcwd() + "/Intcatch_Dataset/" + txt[i][0])))
        train_label.append(binarylab(annotation[:,:,0]))
        print(os.getcwd() + "/" + path + txt[i][0])
        print(os.getcwd() + "/" + path + txt[i][1])
        train_data_path.append(os.getcwd() + "/" + path + txt[i][0])
        train_label_path.append(os.getcwd() + "/" + path + txt[i][1])
    return np.array(train_data), np.array(train_label)

train_data, train_label = prep_data( path, True, True )
#print(len(train_data))
#train_label = np.reshape(train_label,(len(train_data),data_shape,n_labels))
path2= 'Validation/'
val_data, val_label = prep_data( path2, False, False )
#val_label = np.reshape(val_label,(len(val_data),data_shape,n_labels))
# Out:
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/1.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/1-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/2.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/2-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/3.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/3-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/4.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/4-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/5.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/5-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/6.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/6-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/7.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/7-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/8.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/8-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/9.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/9-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/10.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/10-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/11.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/11-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/12.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/12-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/13.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/13-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/14.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/14-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/15.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/15-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/16.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/16-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/17.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/17-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/18.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/18-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/19.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/19-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/20.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/20-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/21.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/21-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/22.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/22-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/23.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/23-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/24.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/24-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/25.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/25-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/26.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/26-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/27.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/27-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/28.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/28-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/29.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/29-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/30.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/30-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/31.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/31-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/32.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/32-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/33.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/33-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/34.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/34-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/35.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/35-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/36.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/36-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/37.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/37-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/38.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/38-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/39.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/39-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/40.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/40-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/41.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/41-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/42.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/42-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/43.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/43-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/44.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/44-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/45.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/45-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/46.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/46-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/47.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/47-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/48.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/48-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/49.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/49-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/50.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/50-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/51.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/51-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/52.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/52-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/53.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/53-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/54.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/54-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/55.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/55-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/56.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/56-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/57.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/57-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/58.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/58-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/59.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/59-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/60.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/60-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/61.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/61-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/62.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/62-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/63.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/63-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/64.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/64-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/65.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/65-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/66.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/66-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/67.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/67-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/68.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/68-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/69.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/69-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/70.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/70-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/71.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/71-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/72.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/72-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/73.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/73-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/74.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/74-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/75.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/75-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/76.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/76-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/77.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/77-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/78.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/78-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/79.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/79-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/80.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/80-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/81.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/81-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/82.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/82-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/83.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/83-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/84.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/84-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/85.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/85-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/86.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/86-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/87.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/87-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/88.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/88-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/89.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/89-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/90.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/90-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/91.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/91-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/92.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/92-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/93.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/93-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/94.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/94-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/95.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/95-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/96.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/96-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/97.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/97-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/98.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/98-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/99.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/99-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/100.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/100-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/101.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/101-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/102.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/102-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/103.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/103-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/104.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/104-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/105.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/105-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/106.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/106-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/107.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/107-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/108.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/108-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/109.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/109-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/110.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/110-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/111.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/111-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/112.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/112-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/113.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/113-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/114.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/114-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/115.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/115-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/116.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/116-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/117.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/117-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/118.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/118-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/119.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/119-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/120.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/120-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/121.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/121-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/122.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/122-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/123.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/123-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/124.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/124-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/125.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/125-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/126.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/126-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/127.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/127-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/128.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/128-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/129.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/129-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/130.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/130-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/131.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/131-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/132.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/132-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/133.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/133-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/134.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/134-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/135.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/135-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/136.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/136-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/137.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/137-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/138.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/138-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/139.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/139-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/140.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/140-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/141.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/141-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/142.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/142-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/143.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/143-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/144.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/144-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/145.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/145-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/146.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/146-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/147.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/147-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/148.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/148-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/149.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/149-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/150.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/150-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/151.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/151-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/152.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/152-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/153.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/153-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/154.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/154-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/155.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/155-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/156.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/156-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/157.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/157-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/158.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/158-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/159.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/159-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/160.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/160-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/161.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/161-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/162.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/162-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/163.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/163-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/164.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/164-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/165.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/165-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/166.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/166-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/167.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/167-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/168.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/168-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/169.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/169-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/170.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/170-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/171.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/171-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/172.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/172-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/173.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/173-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/174.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/174-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/175.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/175-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/176.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/176-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/177.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/177-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/178.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/178-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/179.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/179-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/180.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/180-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/181.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/181-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/182.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/182-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/183.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/183-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/184.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/184-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/185.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/185-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/186.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/186-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/187.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/187-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/188.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/188-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/189.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/189-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/190.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/190-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/191.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Training/191-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/1.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/1-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/2.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/2-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/3.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/3-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/4.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/4-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/5.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/5-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/6.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/6-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/7.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/7-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/8.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/8-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/9.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/9-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/10.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/10-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/11.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/11-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/12.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/12-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/13.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/13-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/14.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/14-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/15.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/15-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/16.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/16-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/17.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/17-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/18.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/18-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/19.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/19-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/20.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/20-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/21.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/21-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/22.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/22-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/23.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/23-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/24.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/24-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/25.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/25-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/26.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/26-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/27.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/27-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/28.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/28-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/29.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/29-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/30.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/30-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/31.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/31-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/32.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/32-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/33.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/33-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/34.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/34-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/35.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/35-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/36.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/36-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/37.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/37-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/38.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/38-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/39.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/39-annotation.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/40.png
# /home/juicyslew/Documents/OARS ML/waterline/oars-waterline/Validation/40-annotation.png

# %%
print(len(train_data))

plt.imshow(train_data[0])
plt.show()
plt.imshow(np.argmax(train_label[0],axis=-1))
plt.show()
plt.imshow(train_data[1])
plt.show()
plt.imshow(np.argmax(train_label[1],axis=-1))
plt.show()
plt.imshow(train_data[2])
plt.show()
plt.imshow(np.argmax(train_label[2],axis=-1))
plt.show()
plt.imshow(train_data[3])
plt.show()
plt.imshow(np.argmax(train_label[3],axis=-1))
plt.show()
plt.imshow(train_data[4])
plt.show()
plt.imshow(np.argmax(train_label[4],axis=-1))
plt.show()
plt.imshow(train_data[5])
plt.show()
plt.imshow(np.argmax(train_label[5],axis=-1))
plt.show()
plt.imshow(train_data[6])
plt.show()
plt.imshow(np.argmax(train_label[6],axis=-1))
plt.show()
plt.imshow(train_data[7])
plt.show()
plt.imshow(np.argmax(train_label[7],axis=-1))
plt.show()
plt.imshow(train_data[8])
plt.show()
plt.imshow(np.argmax(train_label[8],axis=-1))
plt.show()
plt.imshow(train_data[9])
plt.show()
plt.imshow(np.argmax(train_label[9],axis=-1))
plt.show()
# Out:
# 1910

# %% [markdown]
# # augmentation Tensor Layer

# %%
fig = plt.figure(figsize=(10, 3))
fig.suptitle("Origin",fontsize=16)
sub1 = plt.subplot(1,1,1)
sub1.imshow(train_data[0])
sub1.axis('off')
fig = plt.figure(figsize=(10, 3))
fig.suptitle("Zoom and Crop over horizont",fontsize=16)
sub2 = plt.subplot(1, 2, 1)
sub2.imshow(train_data[1])
sub2.axis('off')
sub3 = plt.subplot(1, 2, 2)
sub3.imshow(train_data[2])
sub3.axis('off')
plt.show()

import tensorlayer as tl
x=train_data[0]
fig = plt.figure(figsize=(10, 3))
fig.suptitle("Rotation",fontsize=16)
sub1 = plt.subplot(1,1,1)
x1=tl.prepro.rotation(x,rg=20, is_random=False, fill_mode='reflect') # left right
sub1.imshow(x1)
sub1.axis('off')
plt.show()
fig = plt.figure(figsize=(10, 3))
fig.suptitle("Flip",fontsize=16)
sub1 = plt.subplot(1,1,1)
x2=tl.prepro.flip_axis(x,axis=1, is_random=False) # left right
sub1.imshow(x2)
sub1.axis('off')
plt.show()
fig = plt.figure(figsize=(10, 3))
fig.suptitle("Shear",fontsize=16)
sub1 = plt.subplot(1,1,1)
x3= tl.prepro.shear(x, 0.3, is_random=False, fill_mode='reflect')
sub1.imshow(x3)
sub1.axis('off')
plt.show()
fig = plt.figure(figsize=(10, 3))
fig.suptitle("Zoom",fontsize=16)
sub1 = plt.subplot(1,1,1)
x4 = tl.prepro.zoom(x,zoom_range=[0.5, 0.6], is_random=False, fill_mode='reflect')
sub1.imshow(x4)
sub1.axis('off')
plt.show()
fig = plt.figure(figsize=(10, 3))
fig.suptitle("Brightness",fontsize=16)
sub1 = plt.subplot(1,1,1)
x5 = tl.prepro.brightness(x, gamma=1, gain=1, is_random=True)
sub1.imshow(x5)
sub1.axis('off')
plt.show()



#import tensorlayer as tl
#def distort_img(data):
#    x, y = data
#    x,y=tl.prepro.rotation_multi([x, y],rg=20, is_random=True, fill_mode='reflect') # left right
#    x,y=tl.prepro.shift_multi([x, y], wrg=0.10,hrg=0.10, is_random=True, fill_mode='reflect')
#    x,y=tl.prepro.flip_axis_multi([x, y],axis=2, is_random=True) # left right
#    x,y= tl.prepro.shear_multi([x, y], 0.05, is_random=True, fill_mode='reflect')
#    x,y= tl.prepro.zoom_multi([x, y],zoom_range=[0.9, 1.1], is_random=True, fill_mode='reflect')
#    x,y= tl.prepro.brightness_multi([x, y], gamma=1, gain=1, is_random=True)
    
#    return x,y

#data = tl.prepro.threading_data([_ for _ in zip(train_data, train_label)], distort_img)

# %%
import os
import tensorlayer as tl
with open(path+'data.txt') as f:
    txt = f.readlines()
    txt = [line.split(' ') for line in txt]

image= cv2.imread(os.getcwd() + "/" + path + txt[1][0])
image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
annotation=cv2.imread(os.getcwd() + "/" + path + txt[1][1])

plt.imshow(image)
plt.show()
plt.imshow(visualize(annotation[:,:,0]))
plt.show()

x,y=tl.prepro.rotation_multi([image, annotation],rg=20, is_random=True, fill_mode='reflect') # left right
plt.imshow(x)
plt.show()
plt.imshow(visualize(y[:,:,0]))
plt.show()

x,y=tl.prepro.flip_axis_multi([image, annotation],axis=1, is_random=True) # left right
plt.imshow(x)
plt.show()
plt.imshow(visualize(y[:,:,0]))
plt.show()

x, y = tl.prepro.shear_multi([image, annotation], 0.05, is_random=True, fill_mode='reflect')
plt.imshow(x)
plt.show()
plt.imshow(visualize(y[:,:,0]))
plt.show()

x, y = tl.prepro.zoom_multi([image, annotation],zoom_range=[0.5, 0.7], is_random=True, fill_mode='reflect')
plt.imshow(x)
plt.show()
plt.imshow(visualize(y[:,:,0]))
plt.show()

x,y = tl.prepro.brightness_multi([image, annotation], gamma=1, gain=1, is_random=True)
plt.imshow(x)
plt.show()
plt.imshow(visualize(y[:,:,0]))
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_data, train_label, test_size=0.10, random_state=42)
X_val=val_data
y_val=val_label

del train_data
del train_label
del val_data
del val_label

# %%
print(X_train[0].shape, " --- ", y_train[0].shape )
print("--------")
print(len(X_train), " --- ", len(y_train))
# Out:
# ((160, 160, 3), ' --- ', (160, 160, 2))
# --------
# (1719, ' --- ', 1719)

# %%
from tensorlayer.layers import *
def u_net(x, is_train=False, reuse=False, n_out=1):
    _, nx, ny, nz = x.get_shape().as_list()
    with tf.variable_scope("u_net", reuse=reuse):
        inputs = InputLayer(x, name='inputs')
        conv1 = Conv2d(inputs, 64, (3, 3), act=tf.nn.relu, name='conv1_1')
        conv1 = Conv2d(conv1, 64, (3, 3), act=tf.nn.relu, name='conv1_2')
        pool1 = MaxPool2d(conv1, (2, 2), name='pool1')
        conv2 = Conv2d(pool1, 128, (3, 3), act=tf.nn.relu, name='conv2_1')
        conv2 = Conv2d(conv2, 128, (3, 3), act=tf.nn.relu, name='conv2_2')
        pool2 = MaxPool2d(conv2, (2, 2), name='pool2')
        conv3 = Conv2d(pool2, 256, (3, 3), act=tf.nn.relu, name='conv3_1')
        conv3 = Conv2d(conv3, 256, (3, 3), act=tf.nn.relu, name='conv3_2')
        pool3 = MaxPool2d(conv3, (2, 2), name='pool3')
        conv4 = Conv2d(pool3, 512, (3, 3), act=tf.nn.relu, name='conv4_1')
        conv4 = Conv2d(conv4, 512, (3, 3), act=tf.nn.relu, name='conv4_2')
        pool4 = MaxPool2d(conv4, (2, 2), name='pool4')
        conv5 = Conv2d(pool4, 1024, (3, 3), act=tf.nn.relu, name='conv5_1')
        conv5 = Conv2d(conv5, 1024, (3, 3), act=tf.nn.relu, name='conv5_2')

        up4 = DeConv2d(conv5, 512, (3, 3), (nx/8, ny/8), (2, 2), name='deconv4')
        up4 = ConcatLayer([up4, conv4], 3, name='concat4')
        conv4 = Conv2d(up4, 512, (3, 3), act=tf.nn.relu, name='uconv4_1')
        conv4 = Conv2d(conv4, 512, (3, 3), act=tf.nn.relu, name='uconv4_2')
        up3 = DeConv2d(conv4, 256, (3, 3), (nx/4, ny/4), (2, 2), name='deconv3')
        up3 = ConcatLayer([up3, conv3], 3, name='concat3')
        conv3 = Conv2d(up3, 256, (3, 3), act=tf.nn.relu, name='uconv3_1')
        conv3 = Conv2d(conv3, 256, (3, 3), act=tf.nn.relu, name='uconv3_2')
        up2 = DeConv2d(conv3, 128, (3, 3), (nx/2, ny/2), (2, 2), name='deconv2')
        up2 = ConcatLayer([up2, conv2], 3, name='concat2')
        conv2 = Conv2d(up2, 128, (3, 3), act=tf.nn.relu,  name='uconv2_1')
        conv2 = Conv2d(conv2, 128, (3, 3), act=tf.nn.relu, name='uconv2_2')
        up1 = DeConv2d(conv2, 64, (3, 3), (nx/1, ny/1), (2, 2), name='deconv1')
        up1 = ConcatLayer([up1, conv1] , 3, name='concat1')
        conv1 = Conv2d(up1, 64, (3, 3), act=tf.nn.relu, name='uconv1_1')
        conv1 = Conv2d(conv1, 64, (3, 3), act=tf.nn.relu, name='uconv1_2')
        conv1 = Conv2d(conv1, n_out, (1, 1), act=tf.nn.sigmoid, name='uconv1')
    return conv1

def reduced_u_net(x, is_train=False, reuse=False, n_out=1):
    _, nx, ny, nz = x.get_shape().as_list()
    with tf.variable_scope("u_net", reuse=reuse):
        inputs = InputLayer(x, name='inputs')
        conv1 = Conv2d(inputs, 4, (3, 3), act=tf.nn.relu, name='conv1_1')
        conv1 = Conv2d(conv1, 4, (3, 3), act=tf.nn.relu, name='conv1_2')
        pool1 = MaxPool2d(conv1, (2, 2), name='pool1')
        conv2 = Conv2d(pool1, 8, (3, 3), act=tf.nn.relu, name='conv2_1')
        conv2 = Conv2d(conv2, 8, (3, 3), act=tf.nn.relu, name='conv2_2')
        pool2 = MaxPool2d(conv2, (2, 2), name='pool2')
        conv3 = Conv2d(pool2, 16, (3, 3), act=tf.nn.relu, name='conv3_1')
        conv3 = Conv2d(conv3, 16, (3, 3), act=tf.nn.relu, name='conv3_2')
        pool3 = MaxPool2d(conv3, (2, 2), name='pool3')
        conv4 = Conv2d(pool3, 32, (3, 3), act=tf.nn.relu, name='conv4_1')
        conv4 = Conv2d(conv4, 32, (3, 3), act=tf.nn.relu, name='conv4_2')
        pool4 = MaxPool2d(conv4, (2, 2), name='pool4')
        conv5 = Conv2d(pool4, 64, (3, 3), act=tf.nn.relu, name='conv5_1')
        conv5 = Conv2d(conv5, 64, (3, 3), act=tf.nn.relu, name='conv5_2')

        up4 = DeConv2d(conv5, 32, (3, 3), (nx/8, ny/8), (2, 2), name='deconv4')
        up4 = ConcatLayer([up4, conv4], 3, name='concat4')
        conv4 = Conv2d(up4, 32, (3, 3), act=tf.nn.relu, name='uconv4_1')
        conv4 = Conv2d(conv4, 32, (3, 3), act=tf.nn.relu, name='uconv4_2')
        up3 = DeConv2d(conv4, 16, (3, 3), (nx/4, ny/4), (2, 2), name='deconv3')
        up3 = ConcatLayer([up3, conv3], 3, name='concat3')
        conv3 = Conv2d(up3, 16, (3, 3), act=tf.nn.relu, name='uconv3_1')
        conv3 = Conv2d(conv3, 16, (3, 3), act=tf.nn.relu, name='uconv3_2')
        up2 = DeConv2d(conv3, 8, (3, 3), (nx/2, ny/2), (2, 2), name='deconv2')
        up2 = ConcatLayer([up2, conv2], 3, name='concat2')
        conv2 = Conv2d(up2, 8, (3, 3), act=tf.nn.relu,  name='uconv2_1')
        conv2 = Conv2d(conv2, 8, (3, 3), act=tf.nn.relu, name='uconv2_2')
        up1 = DeConv2d(conv2, 4, (3, 3), (nx/1, ny/1), (2, 2), name='deconv1')
        up1 = ConcatLayer([up1, conv1] , 3, name='concat1')
        conv1 = Conv2d(up1, 4, (3, 3), act=tf.nn.relu, name='uconv1_1')
        conv1 = Conv2d(conv1, 4, (3, 3), act=tf.nn.relu, name='uconv1_2')
        conv1 = Conv2d(conv1, n_out, (1, 1), act=tf.nn.sigmoid, name='uconv1')
    return conv1

# %%
###======================== HYPER-PARAMETERS ============================###
batch_size = 30
lr = 0.0001 
# lr_decay = 0.5
# decay_every = 100
beta1 = 0.9
n_epoch = 20
print_freq_step = 1

# %%
import tensorlayer as tl
import os, time
with tf.device('/cpu:0'):
    sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
    with tf.device('/cpu:0'):
        ###======================== DEFIINE MODEL =======================###
        t_image = tf.placeholder('float32', [batch_size, img_h, img_w, 3], name='input_image')
        ## labels are either 0 or 1
        t_seg = tf.placeholder('float32', [batch_size, img_h, img_w, 2], name='target_segment')
        ## train inference
        net = reduced_u_net(t_image, is_train=True, reuse=False, n_out=2)
        ## test inference
        net_test = reduced_u_net(t_image, is_train=False, reuse=True, n_out=2)
        ###======================== DEFINE LOSS =========================###
        ## train losses
        out_seg = net.outputs
        dice_loss = 1 - tl.cost.dice_coe(out_seg, t_seg, axis=[0,1,2,3])#, 'jaccard', epsilon=1e-5)
        iou_loss = tl.cost.iou_coe(out_seg, t_seg, axis=[0,1,2,3])
        dice_hard = tl.cost.dice_hard_coe(out_seg, t_seg, axis=[0,1,2,3])
        loss = dice_loss
        
        ## test losses
        test_out_seg = net_test.outputs
        test_dice_loss = 1 - tl.cost.dice_coe(test_out_seg, t_seg, axis=[0,1,2,3])#, 'jaccard', epsilon=1e-5)
        test_iou_loss = tl.cost.iou_coe(test_out_seg, t_seg, axis=[0,1,2,3])
        test_dice_hard = tl.cost.dice_hard_coe(test_out_seg, t_seg, axis=[0,1,2,3])

    ###======================== DEFINE TRAIN OPTS =======================###
    t_vars = tl.layers.get_variables_with_name('u_net', True, True)
    with tf.variable_scope('learning_rate'):
        lr_v = tf.Variable(lr, trainable=False)
    train_op = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(loss, var_list=t_vars)
    ###======================== LOAD MODEL ==============================###
    tl.layers.initialize_global_variables(sess)
    ## load existing model if possible
    ## tl.files.load_and_assign_npz(sess=sess, name=save_dir+'/u_net_{}.npz'.format(task), network=net)
tf.summary.FileWriter("logs", tf.get_default_graph()).close()
# Out:
# [TL] InputLayer  u_net/inputs: (30, 160, 160, 3)
# [TL] Conv2dLayer u_net/conv1_1: shape:(3, 3, 3, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv1_2: shape:(3, 3, 64, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool1: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv2_1: shape:(3, 3, 64, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv2_2: shape:(3, 3, 128, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool2: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv3_1: shape:(3, 3, 128, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv3_2: shape:(3, 3, 256, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool3: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv4_1: shape:(3, 3, 256, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv4_2: shape:(3, 3, 512, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool4: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv5_1: shape:(3, 3, 512, 1024) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv5_2: shape:(3, 3, 1024, 1024) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv4: n_filters:512 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat4: axis: 3
# [TL] Conv2dLayer u_net/uconv4_1: shape:(3, 3, 1024, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv4_2: shape:(3, 3, 512, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv3: n_filters:256 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat3: axis: 3
# [TL] Conv2dLayer u_net/uconv3_1: shape:(3, 3, 512, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv3_2: shape:(3, 3, 256, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv2: n_filters:128 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat2: axis: 3
# [TL] Conv2dLayer u_net/uconv2_1: shape:(3, 3, 256, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv2_2: shape:(3, 3, 128, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv1: n_filters:64 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat1: axis: 3
# [TL] Conv2dLayer u_net/uconv1_1: shape:(3, 3, 128, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv1_2: shape:(3, 3, 64, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv1: shape:(1, 1, 64, 2) strides:(1, 1, 1, 1) pad:SAME act:sigmoid
# [TL] InputLayer  u_net/inputs: (30, 160, 160, 3)
# [TL] Conv2dLayer u_net/conv1_1: shape:(3, 3, 3, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv1_2: shape:(3, 3, 64, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool1: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv2_1: shape:(3, 3, 64, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv2_2: shape:(3, 3, 128, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool2: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv3_1: shape:(3, 3, 128, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv3_2: shape:(3, 3, 256, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool3: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv4_1: shape:(3, 3, 256, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv4_2: shape:(3, 3, 512, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] PoolLayer   u_net/pool4: ksize:[1, 2, 2, 1] strides:[1, 2, 2, 1] padding:SAME pool:max_pool
# [TL] Conv2dLayer u_net/conv5_1: shape:(3, 3, 512, 1024) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/conv5_2: shape:(3, 3, 1024, 1024) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv4: n_filters:512 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat4: axis: 3
# [TL] Conv2dLayer u_net/uconv4_1: shape:(3, 3, 1024, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv4_2: shape:(3, 3, 512, 512) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv3: n_filters:256 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat3: axis: 3
# [TL] Conv2dLayer u_net/uconv3_1: shape:(3, 3, 512, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv3_2: shape:(3, 3, 256, 256) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv2: n_filters:128 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat2: axis: 3
# [TL] Conv2dLayer u_net/uconv2_1: shape:(3, 3, 256, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv2_2: shape:(3, 3, 128, 128) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] DeConv2d deconv1: n_filters:64 strides:(2, 2) pad:SAME act:identity
# [TL] ConcatLayer u_net/concat1: axis: 3
# [TL] Conv2dLayer u_net/uconv1_1: shape:(3, 3, 128, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv1_2: shape:(3, 3, 64, 64) strides:(1, 1, 1, 1) pad:SAME act:relu
# [TL] Conv2dLayer u_net/uconv1: shape:(1, 1, 64, 2) strides:(1, 1, 1, 1) pad:SAME act:sigmoid
# [TL]   [*] geting variables with u_net
# [TL]   got   0: u_net/conv1_1/W_conv2d:0   (3, 3, 3, 64)
# [TL]   got   1: u_net/conv1_1/b_conv2d:0   (64,)
# [TL]   got   2: u_net/conv1_2/W_conv2d:0   (3, 3, 64, 64)
# [TL]   got   3: u_net/conv1_2/b_conv2d:0   (64,)
# [TL]   got   4: u_net/conv2_1/W_conv2d:0   (3, 3, 64, 128)
# [TL]   got   5: u_net/conv2_1/b_conv2d:0   (128,)
# [TL]   got   6: u_net/conv2_2/W_conv2d:0   (3, 3, 128, 128)
# [TL]   got   7: u_net/conv2_2/b_conv2d:0   (128,)
# [TL]   got   8: u_net/conv3_1/W_conv2d:0   (3, 3, 128, 256)
# [TL]   got   9: u_net/conv3_1/b_conv2d:0   (256,)
# [TL]   got  10: u_net/conv3_2/W_conv2d:0   (3, 3, 256, 256)
# [TL]   got  11: u_net/conv3_2/b_conv2d:0   (256,)
# [TL]   got  12: u_net/conv4_1/W_conv2d:0   (3, 3, 256, 512)
# [TL]   got  13: u_net/conv4_1/b_conv2d:0   (512,)
# [TL]   got  14: u_net/conv4_2/W_conv2d:0   (3, 3, 512, 512)
# [TL]   got  15: u_net/conv4_2/b_conv2d:0   (512,)
# [TL]   got  16: u_net/conv5_1/W_conv2d:0   (3, 3, 512, 1024)
# [TL]   got  17: u_net/conv5_1/b_conv2d:0   (1024,)
# [TL]   got  18: u_net/conv5_2/W_conv2d:0   (3, 3, 1024, 1024)
# [TL]   got  19: u_net/conv5_2/b_conv2d:0   (1024,)
# [TL]   got  20: u_net/deconv4/deconv4/weights:0   (3, 3, 512, 1024)
# [TL]   got  21: u_net/deconv4/deconv4/biases:0   (512,)
# [TL]   got  22: u_net/uconv4_1/W_conv2d:0   (3, 3, 1024, 512)
# [TL]   got  23: u_net/uconv4_1/b_conv2d:0   (512,)
# [TL]   got  24: u_net/uconv4_2/W_conv2d:0   (3, 3, 512, 512)
# [TL]   got  25: u_net/uconv4_2/b_conv2d:0   (512,)
# [TL]   got  26: u_net/deconv3/deconv3/weights:0   (3, 3, 256, 512)
# [TL]   got  27: u_net/deconv3/deconv3/biases:0   (256,)
# [TL]   got  28: u_net/uconv3_1/W_conv2d:0   (3, 3, 512, 256)
# [TL]   got  29: u_net/uconv3_1/b_conv2d:0   (256,)
# [TL]   got  30: u_net/uconv3_2/W_conv2d:0   (3, 3, 256, 256)
# [TL]   got  31: u_net/uconv3_2/b_conv2d:0   (256,)
# [TL]   got  32: u_net/deconv2/deconv2/weights:0   (3, 3, 128, 256)
# [TL]   got  33: u_net/deconv2/deconv2/biases:0   (128,)
# [TL]   got  34: u_net/uconv2_1/W_conv2d:0   (3, 3, 256, 128)
# [TL]   got  35: u_net/uconv2_1/b_conv2d:0   (128,)
# [TL]   got  36: u_net/uconv2_2/W_conv2d:0   (3, 3, 128, 128)
# [TL]   got  37: u_net/uconv2_2/b_conv2d:0   (128,)
# [TL]   got  38: u_net/deconv1/deconv1/weights:0   (3, 3, 64, 128)
# [TL]   got  39: u_net/deconv1/deconv1/biases:0   (64,)
# [TL]   got  40: u_net/uconv1_1/W_conv2d:0   (3, 3, 128, 64)
# [TL]   got  41: u_net/uconv1_1/b_conv2d:0   (64,)
# [TL]   got  42: u_net/uconv1_2/W_conv2d:0   (3, 3, 64, 64)
# [TL]   got  43: u_net/uconv1_2/b_conv2d:0   (64,)
# [TL]   got  44: u_net/uconv1/W_conv2d:0   (1, 1, 64, 2)
# [TL]   got  45: u_net/uconv1/b_conv2d:0   (2,)

# %%
#Training
for epoch in range(0, n_epoch+1):
    epoch_time = time.time()
    total_dice, total_iou, total_dice_hard, n_batch = 0, 0, 0, 0
    for batch in tl.iterate.minibatches(inputs=X_train, targets=y_train,
                                batch_size=batch_size, shuffle=True):
        images, labels = batch
        step_time = time.time()
        # Data augmentation
        #data = tl.prepro.threading_data([_ for _ in zip(images, labels)], distort_img)
        #images, labels = data.transpose((1,0,2,3,4))
        
        ## update network
        _, _dice, _iou, _diceh, out = sess.run([train_op,
                dice_loss, iou_loss, dice_hard, net.outputs],
                {t_image: images, t_seg: labels})


        total_dice += _dice; total_iou += _iou; total_dice_hard += _diceh
        n_batch += 1
        if n_batch % print_freq_step == 0:
            print("Epoch %d step %d 1-dice: %f hard-dice: %f iou: %f took %fs"
            % (epoch, n_batch, _dice, _diceh, _iou, time.time()-step_time))
            plt.imshow(images[0])
            plt.show()
            plt.imshow(np.argmax(labels[0],axis=-1))
            plt.show()
            plt.imshow(np.argmax(out[0],axis=-1))
            plt.show()
            

        ## check model fail
        if np.isnan(_dice):
            exit(" ** NaN loss found during training, stop training")
        if np.isnan(out).any():
            exit(" ** NaN found in output images during training, stop training")

    print(" ** Epoch [%d/%d] train 1-dice: %f hard-dice: %f iou: %f took %fs" %
            (epoch, n_epoch, total_dice/n_batch, total_dice_hard/n_batch, total_iou/n_batch, time.time()-epoch_time))

    ###======================== EVALUATION TEST SET ==========================###
    total_dice, total_iou, total_dice_hard, n_batch = 0, 0, 0, 0
    for batch in tl.iterate.minibatches(inputs=X_test, targets=y_test,
                                    batch_size=batch_size, shuffle=True):
        b_images, b_labels = batch
        _dice, _iou, _diceh, out = sess.run([test_dice_loss,
                test_iou_loss, test_dice_hard, net_test.outputs],
                {t_image: b_images, t_seg: b_labels})
        total_dice += _dice; total_iou += _iou; total_dice_hard += _diceh
        n_batch += 1

    print(" **"+" "*12+"test 1-dice: %f hard-dice: %f iou: %f" %
            (total_dice/n_batch, total_dice_hard/n_batch, total_iou/n_batch))
    
    
    # save the test model as 'u_net_test_model'
    saver = tf.train.Saver()
    saver.save(sess, './Tensorflow_models/u_net_test_model')
# Out:
# Epoch 0 step 1 1-dice: 0.333333 hard-dice: 0.648080 iou: 0.479377 took 103.343053s
# Epoch 0 step 2 1-dice: 0.333328 hard-dice: 0.666667 iou: 0.500000 took 87.306693s
# Epoch 0 step 3 1-dice: 0.333317 hard-dice: 0.666667 iou: 0.500000 took 60.261746s
# Epoch 0 step 4 1-dice: 0.333308 hard-dice: 0.666667 iou: 0.500000 took 58.197724s
# Epoch 0 step 5 1-dice: 0.333255 hard-dice: 0.666667 iou: 0.500000 took 54.927670s
# Epoch 0 step 6 1-dice: 0.333239 hard-dice: 0.666667 iou: 0.500000 took 55.551870s
# Epoch 0 step 7 1-dice: 0.333209 hard-dice: 0.666667 iou: 0.500000 took 60.501147s

# %%
import tensorflow as tf
 
sess=tf.Session()    
#First let's load meta graph and restore weights
saver = tf.train.import_meta_graph('./Tensorflow_models/u_net_test_model.meta')
saver.restore(sess,tf.train.latest_checkpoint('./Tensorflow_models/'))
 
graph = tf.get_default_graph()
i = graph.get_tensor_by_name("input_image:0")
l = graph.get_tensor_by_name("target_segment:0")
feed_dict ={i:X_val,l:y_val}

# %%
save_dir="."
###======================== SAVE MODEL ==========================###
tl.files.save_npz(net.all_params, name=save_dir+'/u_net_{}.npz', sess=sess)
